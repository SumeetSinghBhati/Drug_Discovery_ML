# %% [markdown]
# # **Bioinformatics Project - Computational Drug Discovery [Part 1]**
#
# In **Part 1**, we will be performing Data Collection and Pre-Processing from the ChEMBL Database.
#
# **Prepared By :** *Sumeet*

# %% [markdown]
# ## **ChEMBL Database**
#
# The [*ChEMBL Database*](https://www.ebi.ac.uk/chembl/) is a database that contains curated bioactivity data of more than 2 million compounds.

# %% [markdown]
# ## **Installing libraries**

# %% [markdown]
# Install the ChEMBL web service package so that we can retrieve bioactivity data from the ChEMBL Database.

# %%
! pip install chembl_webresource_client

# %% [markdown]
# ## **Importing libraries**

# %%
# Import necessary libraries
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# ## **Search for Target protein**

# %% [markdown]
# ### **Target search for Butyrylcholinesterase**

# %%
# Target search for coronavirus
target = new_client.target
target_query = target.search('Butyrylcholinesterase')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#                                     cross_references           organism  \
# 0  [{'xref_id': 'P06276', 'xref_name': None, 'xre...       Homo sapiens
# 1                                                 []       Homo sapiens
# 2  [{'xref_id': 'NBK23441', 'xref_name': 'Butyryl...       Mus musculus
# 3  [{'xref_id': 'Q9JKC1', 'xref_name': None, 'xre...  Rattus norvegicus
# 4  [{'xref_id': 'Q9N1N9', 'xref_name': None, 'xre...     Equus caballus
# 5                                                 []  Rattus norvegicus
#
#                                            pref_name  score  \
# 0                              Butyrylcholinesterase   28.0
# 1                       Cholinesterases; ACHE & BCHE   28.0
# 2                              Butyrylcholinesterase   18.0
# 3                              Butyrylcholinesterase   18.0
# 4                              Butyrylcholinesterase   18.0
# 5  Acetylcholinesterase and butyrylcholinesterase...   10.0
#
# ...

# %% [markdown]
# ### **Select and retrieve bioactivity data for *Butyrylcholinesterase* (first entry)**

# %% [markdown]
# We will assign the fifth entry (which corresponds to the target protein, *Butyrylcholinesterase*) to the ***selected_target*** variable

# %%
selected_target = targets.target_chembl_id[0]
selected_target
# Out:
# 'CHEMBL1914'

# %% [markdown]
# Here, we will retrieve only bioactivity data for *Butyrylcholinesterase* (CHEMBL1914) that are reported as pChEMBL values.

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df = pd.DataFrame.from_dict(res)

# %%
df
# Out:
#                                             action_type activity_comment  \
# 0                                                  None             None
# 1                                                  None             None
# 2                                                  None             None
# 3                                                  None             None
# 4                                                  None             None
# ...                                                 ...              ...
# 4812  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 4813  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 4814  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 4815  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 4816  {'action_type': 'INHIBITOR', 'description': 'N...             None
#
#       activity_id                                activity_properties  \
# ...

# %% [markdown]
# Finally we will save the resulting bioactivity data to a CSV file **bioactivity_data.csv**.

# %%
df.to_csv('Butyrylcholinesterase_01_bioactivity_data_raw.csv', index=False)

# %% [markdown]
# ## **Handling missing data**
# If any compounds has missing value for the **standard_value** and **canonical_smiles** column then drop it.

# %%
df2 = df[df.standard_value.notna()]
df2 = df2[df.canonical_smiles.notna()]
df2
# Out:
# C:\Users\sumee\AppData\Local\Temp\ipykernel_24068\3852201246.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df2 = df2[df.canonical_smiles.notna()]
#                                             action_type activity_comment  \
# 0                                                  None             None
# 1                                                  None             None
# 2                                                  None             None
# 3                                                  None             None
# 4                                                  None             None
# ...                                                 ...              ...
# 4812  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 4813  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 4814  {'action_type': 'INHIBITOR', 'description': 'N...             None
# ...

# %%
len(df2.canonical_smiles.unique())
# Out:
# 3852

# %%
df2_nr = df2.drop_duplicates(['canonical_smiles'])
df2_nr
# Out:
#                                             action_type activity_comment  \
# 0                                                  None             None
# 1                                                  None             None
# 2                                                  None             None
# 3                                                  None             None
# 4                                                  None             None
# ...                                                 ...              ...
# 4809  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 4810  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 4811  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 4812  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 4814  {'action_type': 'INHIBITOR', 'description': 'N...             None
#
#       activity_id                                activity_properties  \
# ...

# %% [markdown]
# ## **Data pre-processing of the bioactivity data**

# %% [markdown]
# ### **Combine the 3 columns (molecule_chembl_id,canonical_smiles,standard_value) and bioactivity_class into a DataFrame**

# %%
selection = ['molecule_chembl_id','canonical_smiles','standard_value']
df3 = df2_nr[selection]
df3
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0          CHEMBL133897              CCOc1nn(-c2cccc(OCc3ccccc3)c2)c(=O)o1
# 1          CHEMBL336398         O=C(N1CCCCC1)n1nc(-c2ccc(Cl)cc2)nc1SCC1CC1
# 2          CHEMBL131588  CN(C(=O)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F)c1ccccc1
# 3          CHEMBL130628      O=C(N1CCCCC1)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F
# 4          CHEMBL130478          CSc1nc(-c2ccc(OC(F)(F)F)cc2)nn1C(=O)N(C)C
# ...                 ...                                                ...
# 4809      CHEMBL5270598         O=C1CC2CCc3ccsc3C2=NN1CN1CCN(Cc2ccccc2)CC1
# 4810      CHEMBL5285633     O=C1CC2CCCc3ccsc3C2=NN1CCCCN1CCN(Cc2ccccc2)CC1
# 4811      CHEMBL5283494        O=C1CC2CCc3ccsc3C2=NN1CCN1CCN(Cc2ccccc2)CC1
# 4812      CHEMBL5283557  O=C1CC2CCc3ccsc3C2=NN1Cc1ccc(CN2CCN(Cc3ccccc3)...
# 4814      CHEMBL5288465      O=C1CC2CCc3sccc3C2=NN1CCCCN1CCN(Cc2ccccc2)CC1
#
#      standard_value
# 0             920.0
# 1             900.0
# ...

# %% [markdown]
# Saves dataframe to CSV file

# %%
df3.to_csv('Butyrylcholinesterase_02_bioactivity_data_preprocessed.csv', index=False)

# %% [markdown]
# ### **Labeling compounds as either being active, inactive or intermediate**
# The bioactivity data is in the IC50 unit. Compounds having values of less than 1000 nM will be considered to be **active** while those greater than 10,000 nM will be considered to be **inactive**. As for those values in between 1,000 and 10,000 nM will be referred to as **intermediate**.

# %%
df4 = pd.read_csv('Butyrylcholinesterase_02_bioactivity_data_preprocessed.csv')

# %%
bioactivity_threshold = []
for i in df4.standard_value:
  if float(i) >= 10000:
    bioactivity_threshold.append("inactive")
  elif float(i) <= 1000:
    bioactivity_threshold.append("active")
  else:
    bioactivity_threshold.append("intermediate")

# %%
bioactivity_class = pd.Series(bioactivity_threshold, name='class')
df5 = pd.concat([df4, bioactivity_class], axis=1)
df5
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0          CHEMBL133897              CCOc1nn(-c2cccc(OCc3ccccc3)c2)c(=O)o1
# 1          CHEMBL336398         O=C(N1CCCCC1)n1nc(-c2ccc(Cl)cc2)nc1SCC1CC1
# 2          CHEMBL131588  CN(C(=O)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F)c1ccccc1
# 3          CHEMBL130628      O=C(N1CCCCC1)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F
# 4          CHEMBL130478          CSc1nc(-c2ccc(OC(F)(F)F)cc2)nn1C(=O)N(C)C
# ...                 ...                                                ...
# 3847      CHEMBL5270598         O=C1CC2CCc3ccsc3C2=NN1CN1CCN(Cc2ccccc2)CC1
# 3848      CHEMBL5285633     O=C1CC2CCCc3ccsc3C2=NN1CCCCN1CCN(Cc2ccccc2)CC1
# 3849      CHEMBL5283494        O=C1CC2CCc3ccsc3C2=NN1CCN1CCN(Cc2ccccc2)CC1
# 3850      CHEMBL5283557  O=C1CC2CCc3ccsc3C2=NN1Cc1ccc(CN2CCN(Cc3ccccc3)...
# 3851      CHEMBL5288465      O=C1CC2CCc3sccc3C2=NN1CCCCN1CCN(Cc2ccccc2)CC1
#
#       standard_value         class
# ...

# %% [markdown]
# Saves dataframe to CSV file

# %%
df5.to_csv('Butyrylcholinesterase_03_bioactivity_data_curated.csv', index=False)

# %% [markdown]
# ---
